# %%
from djitney.models import Station,Line,Stop
import random 


Line.objects.all()
Stop.objects.all()

rand_num = random.randrange(len(Station.objects.all()))
lines_all = Line.objects.all()
station_all = Station.objects.all()

print(len(lines_all))

#stop_obj= Stop(lines_all[0],station_all[0],1)
#stop_obj.save()



for j in range(0,len(station_all)):
    for k in range(0,len(lines_all)):
        print(f' {lines_all[k]} -  {station_all[j]}')
        stop_obj = Stop(line=lines_all[k],station=station_all[j],stop_number=k)
        stop_obj.save()
        #for k in range(1,6):
            #stop_obj =
# Out:
# 3
#  Reticulated -  Welsh (♿)
#  Diamond -  Welsh (♿)
#  Monty -  Welsh (♿)
#  Reticulated -  Hackney (♿)
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/Documents/lab/django_lab/venv/lib/python3.9/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      85             else:
# ---> 86                 return self.cursor.execute(sql, params)
#      87
#
# ~/Documents/lab/django_lab/venv/lib/python3.9/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     395         query = self.convert_query(query)
# --> 396         return Database.Cursor.execute(self, query, params)
#     397
#
# IntegrityError: UNIQUE constraint failed: djitney_stop.line_id, djitney_stop.stop_number
#
# The above exception was the direct cause of the following exception:
#
# ...
